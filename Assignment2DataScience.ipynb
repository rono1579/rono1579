# %% [markdown]
# <a href="https://colab.research.google.com/github/rono1579/rono1579/blob/main/Assignment2DataScience.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
yusufdf = pd.read_csv('/content/DATASET2.csv')

yusufdf.head()
# Out:
#    Weather  Road  Time  Traffic  Outcome
# 0        1     1     1        1        0
# 1        2     1     1        1        1
# 2        3     1     1        1        2
# 3        1     2     1        1        0
# 4        2     2     1        1        1

# %%
yusufdf.describe()
# Out:
#          Weather       Road       Time    Traffic    Outcome
# count  36.000000  36.000000  36.000000  36.000000  36.000000
# mean    2.000000   2.000000   0.500000   0.500000   1.444444
# std     0.828079   0.828079   0.507093   0.507093   0.876501
# min     1.000000   1.000000   0.000000   0.000000   0.000000
# 25%     1.000000   1.000000   0.000000   0.000000   1.000000
# 50%     2.000000   2.000000   0.500000   0.500000   1.000000
# 75%     3.000000   3.000000   1.000000   1.000000   2.000000
# max     3.000000   3.000000   1.000000   1.000000   3.000000

# %%
X = yusufdf.drop('Outcome', axis = 1)
y = yusufdf['Outcome']

import seaborn as sns
sns.heatmap(yusufdf)
# Out:
# <Axes: >

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y, test_size=0.2, random_state=0)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train,y_train)

from sklearn.metrics import mean_absolute_error
accuracy = mean_absolute_error(y_test,prediction)
accuracy
# Out:
# 0.39508232755175454

# %%
prediction = model.predict(X_test)
prediction
# Out:
# array([0.88098473, 2.18008153, 2.30001599, 0.23435377, 1.9992007 ,
#        1.65338502, 1.36851571, 1.22680042])

# %%
import joblib
joblib.dump(model,'Road Accident Predictor')
# Out:
# ['Road Accident Predictor']
